# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
data = sns.load_dataset('iris')
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.rename(columns={'sepal_length':'SL','sepal_width':'SW','petal_length':'PL','petal_width':'PW'},inplace=True)

# %%
data.head()
# Out:
#     SL   SW   PL   PW species
# 0  5.1  3.5  1.4  0.2  setosa
# 1  4.9  3.0  1.4  0.2  setosa
# 2  4.7  3.2  1.3  0.2  setosa
# 3  4.6  3.1  1.5  0.2  setosa
# 4  5.0  3.6  1.4  0.2  setosa

# %%
data['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris_setosa=data[data['species']=='setosa']
iris_versicolor=data[data['species']=='versicolor']
iris_virginica=data[data['species']=='virginica']

#here we are creating 3different dataframe and storing values of previous data

# %%
#1--->MEAN(Average)

# %%
#sepal width
print(np.mean(iris_setosa['SW']))
print(np.mean(iris_versicolor['SW']))
print(np.mean(iris_virginica['SW']))
# Out:
# 3.428000000000001
# 2.7700000000000005
# 2.9739999999999998

# %%
#sepal length
print(np.mean(iris_setosa['SL']))
print(np.mean(iris_versicolor['SL']))
print(np.mean(iris_virginica['SL']))
# Out:
# 5.005999999999999
# 5.936
# 6.587999999999998

# %%
#petal width
print(np.mean(iris_setosa['PW']))
print(np.mean(iris_versicolor['PW']))
print(np.mean(iris_virginica['PW']))
# Out:
# 0.2459999999999999
# 1.3259999999999998
# 2.026

# %%
#petal length
print(np.mean(iris_setosa['PL']))
print(np.mean(iris_versicolor['PL']))
print(np.mean(iris_virginica['PL']))
# Out:
# 1.4620000000000002
# 4.26
# 5.552

# %%
#the problem of outliers
#Range of setosa petal width is btw 1 to 2

# %%
plt.hist(iris_setosa['PL'])
# Out:
# (array([ 1.,  1.,  2.,  7., 13., 13.,  7.,  4.,  0.,  2.]),
#  array([1.  , 1.09, 1.18, 1.27, 1.36, 1.45, 1.54, 1.63, 1.72, 1.81, 1.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#if we add an outlier of 50 at the end
np.mean(np.append(iris_setosa['PL'],50))
# it will change the whole structure and exceed the previous range
# Out:
# 2.4137254901960787

# %%
#petal length
print(np.mean(iris_setosa['PL']))
print(np.mean(iris_versicolor['PL']))
print(np.mean(iris_virginica['PL']))
# Out:
# 1.4620000000000002
# 4.26
# 5.552

# %%
#median(bich ka term/[(n+1)/2])


#the good things about median is :-there is no changes in median after appending 50 as outlier
np.median(np.append(iris_setosa['PL'],50))
# jb v outliers mile humasa use median and not mean
# Out:
# 1.5

# %%
arr=np.array([1,4,5,8,12,600,700,800,100000])
np.median(arr)
# Out:
# 12.0

# %%
#mode(sbse jyada jiska frequency h)

# %%
from scipy import stats


print(stats.mode(iris_setosa['PL']))
print(stats.mode(iris_versicolor['PL']))
print(stats.mode(iris_virginica['PL']))
# Out:
# ModeResult(mode=array([1.4]), count=array([13]))
# ModeResult(mode=array([4.5]), count=array([7]))
# ModeResult(mode=array([5.1]), count=array([7]))

# %%
#which one should you use?
# we should use all 3 to have a fair idea of the certrality of the data
