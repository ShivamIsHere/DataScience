# %%
#  81eafd1b977755444e69def658824604
# json viewer
#     https://api.themoviedb.org/3/movie/popular?api_key=81eafd1b977755444e69def658824604&language=en-US&page=1

# %%
import requests
import pandas as pd

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=81eafd1b977755444e69def658824604&language=en-US&page=1').json()

# %%
# response.json ()

# %%
# response.text

# %%
response
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/d6MhreFdMHONqX3iZlJGCF8UkIt.jpg',
#    'genre_ids': [28, 12, 14],
#    'id': 436270,
#    'original_language': 'en',
#    'original_title': 'Black Adam',
#    'overview': 'Nearly 5,000 years after he was bestowed with the almighty powers of the Egyptian gods—and imprisoned just as quickly—Black Adam is freed from his earthly tomb, ready to unleash his unique form of justice on the modern world.',
#    'popularity': 4416.78,
#    'poster_path': '/3zXceNTtyj5FLjwQXuPvLYK5YYL.jpg',
#    'release_date': '2022-10-19',
#    'title': 'Black Adam',
#    'video': False,
#    'vote_average': 7.1,
#    'vote_count': 501},
#   {'adult': False,
#    'backdrop_path': '/tIX6j3NzadlwGcJ52nuWdmtOQkg.jpg',
#    'genre_ids': [27, 53, 9648],
#    'id': 717728,
#    'original_language': 'en',
#    'original_title': 'Jeepers Creepers: Reborn',
# ...

# %%
for i in response['results']:
    print(i['title'])
# Out:
# Black Adam
# Jeepers Creepers: Reborn
# Terrifier 2
# Fullmetal Alchemist: The Final Alchemy
# Halloween Ends
# Orphan: First Kill
# Fall
# Project Gemini
# Bullet Train
# The Battle at Lake Changjin: Water Gate Bridge
# Piggy
# Athena
# Hocus Pocus 2
# Grimcutty
# The Infernal Machine
# Secret Headquarters
# Blackout
# Terrifier
# Pinocchio
# Beast

# %%
for i in response['results']:
    print(i['title'], i['vote_average'])
# Out:
# Black Adam 7.1
# Jeepers Creepers: Reborn 5.8
# Terrifier 2 7.5
# Fullmetal Alchemist: The Final Alchemy 6.3
# Halloween Ends 6.7
# Orphan: First Kill 6.8
# Fall 7.3
# Project Gemini 5.5
# Bullet Train 7.5
# The Battle at Lake Changjin: Water Gate Bridge 6.3
# Piggy 7
# Athena 6.6
# Hocus Pocus 2 7.6
# Grimcutty 5.8
# The Infernal Machine 7
# Secret Headquarters 6.8
# Blackout 5.5
# Terrifier 6.5
# Pinocchio 6.7
# Beast 7

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]


for i in response['results']:
    
    popularity.append(i['popularity'])
    vote_count.append(i['vote_count'])
    original_language.append(i['original_language'])
    title.append(i['title'])
    vote_average.append(i['vote_average'])
    overview.append(i['overview'])
    release_date.append(i['release_date'])
    
d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}



df=pd.DataFrame(d)

df
# Out:
#                                              title  \
# 0                                       Black Adam
# 1                         Jeepers Creepers: Reborn
# 2                                      Terrifier 2
# 3           Fullmetal Alchemist: The Final Alchemy
# 4                                   Halloween Ends
# 5                               Orphan: First Kill
# 6                                             Fall
# 7                                   Project Gemini
# 8                                     Bullet Train
# 9   The Battle at Lake Changjin: Water Gate Bridge
# 10                                           Piggy
# 11                                          Athena
# 12                                   Hocus Pocus 2
# 13                                       Grimcutty
# 14                            The Infernal Machine
# 15                             Secret Headquarters
# 16                                        Blackout
# ...

# %%
final=pd.DataFrame()
for j in range(1,501):
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=81eafd1b977755444e69def658824604&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]


    for i in response['results']:
        try:
            release_date.append(i['release_date'])
        except KeyError:
            continue
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])

    d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}



    df=pd.DataFrame(d)
    
    final=final.append(df)
final
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_6932\4280210431.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_6932\4280210431.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_6932\4280210431.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_6932\4280210431.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)
# ...

# %%
final=pd.DataFrame()
for j in range(1,501):
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=81eafd1b977755444e69def658824604&language=en-US&page={}'.format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]


    for i in response['results']:
        try:
            release_date.append(i['release_date'])
        except KeyError:
            continue
        popularity.append(i['popularity'])
        vote_count.append(i['vote_count'])
        original_language.append(i['original_language'])
        title.append(i['title'])
        vote_average.append(i['vote_average'])
        overview.append(i['overview'])

    d={'title':title,'overview':overview,'original_language':original_language,'release_date':release_date,'popularity':popularity,'vote_count':vote_count,'vote_average':vote_average}



    df=pd.DataFrame(d)
    
    final=final.append(df,ignore_index=True)
final
# Out:
# C:\Users\Shivam\AppData\Local\Temp\ipykernel_6932\1090562172.py:31: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)
#                                         title  \
# 0                                  Black Adam
# 1                    Jeepers Creepers: Reborn
# 2                                 Terrifier 2
# 3      Fullmetal Alchemist: The Final Alchemy
# 4                              Halloween Ends
# ...                                       ...
# 9984  Mardock Scramble: The First Compression
# 9985                        Operation Seawolf
# 9986                     The Boys in the Band
# 9987                                Atlantics
# 9988                                     Meru
#
#                                                overview original_language  \
# 0     Nearly 5,000 years after he was bestowed with ...                en
# ...

# %%
final.to_csv('movie.csv')
